# %% [markdown]
# ### 从高维数据向低维数据的映射

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.empty((100,2))
X[:,0] = np.random.uniform(0.,100.,size=100)
X[:,1] = 0.75 * X[:,0] + 3. + np.random.normal(0,10.,size=100)

# %%
from playML.PCA import PCA
pca = PCA(n_components=2)
pca.fit(X)
# Out:
# PCA(n_components=2)

# %%
pca.components_
# Out:
# array([[ 0.77046456,  0.63748283],
#        [-0.63747985,  0.77046703]])

# %%
pca = PCA(n_components=1)
pca.fit(X)
pca.components_
# Out:
# array([[0.77046458, 0.63748281]])

# %% [markdown]
# ### transform 高维数据映射为低维数据

# %%
X_reduction = pca.transform(X)  
X_reduction[:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-23e7d0e32f46> in <module>()
# ----> 1 X_reduction = pca.transform(X)  # 高维数据映射为低维数据
#       2 X_reduction[:10]
#
# NameError: name 'pca' is not defined

# %%
# 还原
X_restore = pca.inverse_transform(X_reduction)
X_restore.shape
# Out:
# (100, 2)

# %% [markdown]
# 画出transform前后的数据, 蓝色是原始数据, 红色是inverse_transform后的数据,即低维映射成高维数据

# %%
plt.scatter(X[:,0],X[:,1],color='b',alpha=0.5)
plt.scatter(X_restore[:,0],X_restore[:,1],color='r',alpha=0.5)
plt.show()

# %% [markdown]
# ### scikit-learn 中的PCA

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=1)
pca.fit(X)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=1, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
pca.components_
# Out:
# array([[0.77046461, 0.63748278]])

# %%
X_reduction = pca.transform(X)
X_restore = pca.inverse_transform(X_reduction)

# %%
plt.scatter(X[:,0], X[:,1], color='b', alpha=0.5)
plt.scatter(X_restore[:,0], X_restore[:,1], color='r', alpha=0.5)
plt.show()
