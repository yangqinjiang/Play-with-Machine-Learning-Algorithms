# %% [markdown]
# ### 什么是多项式回归

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(seed=666)
x = np.random.uniform(-3,3,size=100)
X = x.reshape(-1,1) # 变成多行单列

# 一元二次元方程
y = 0.5 * (x ** 2) + x + 2 + np.random.normal(0,1,100)

# %%
plt.scatter(x,y)
plt.show()

# %% [markdown]
# ### 线性回归?  一条直线, 表达不了

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(X,y)
y_predict = lin_reg.predict(X) # 预测

# %%
plt.scatter(x,y)
plt.plot(x,y_predict,color='r')
plt.show()

# %% [markdown]
# ### 解决方案: 添加一个特征

# %%
X2 = np.hstack([X,X**2])  # 将X , X^2 组合成新的矩阵
X2.shape
# Out:
# (100, 2)

# %%
lin_reg2 = LinearRegression()
lin_reg2.fit(X2,y)
y_predict2 = lin_reg2.predict(X2)

# %%
plt.scatter(x,y)
##要生成平滑的曲线，需要对x进行排序
plt.plot(np.sort(x),y_predict2[np.argsort(x)],color='r')
plt.show()

# %%
lin_reg2.coef_  # X和X^2的系数
# Out:
# array([1.00211316, 0.50409402])

# %%
lin_reg2.intercept_ #
# Out:
# 2.015310151924672
